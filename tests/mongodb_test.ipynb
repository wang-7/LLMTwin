# %%
from llmtwin.base import BaseDocument

# %%
class SaleDocument(BaseDocument):

    @classmethod
    def get_collection_name(cls):
        return 'sales'
    
result = SaleDocument.find_one(item='abc')
print(result)
# Out:
# {'_id': ObjectId('693182123b603b38dd456139'), 'item': 'abc', 'price': 10, 'quantity': 2, 'date': datetime.datetime(2014, 3, 1, 8, 0)}
