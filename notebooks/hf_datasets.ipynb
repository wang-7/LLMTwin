# %%
import os

os.environ["HF_ENDPOINT"] = "https://hf-mirror.com"
# os.environ["HF_ENDPOINT"] = "https://huggingface.hust.edu.cn"

from huggingface_hub import hf_hub_url
print(hf_hub_url("nyu-mll/glue", "README.md"))
# Out:
# https://hf-mirror.com/nyu-mll/glue/resolve/main/README.md

# %%
from datasets import load_dataset_builder

# ds_builder = load_dataset_builder('cornell-movie-review-data/rotten_tomatoes')
ds_builder = load_dataset_builder('mlabonne/FineTome-Alpaca-100k')
print(ds_builder.info)
# ds_builder.info.description
# Out:
# DatasetInfo(description='', citation='', homepage='', license='', features={'source': Value('string'), 'score': Value('float64'), 'instruction': Value('string'), 'output': Value('string')}, post_processed=None, supervised_keys=None, builder_name='parquet', dataset_name='fine_tome-alpaca-100k', config_name='default', version=0.0.0, splits={'train': SplitInfo(name='train', num_bytes=178325789, num_examples=100000, shard_lengths=None, dataset_name=None)}, download_checksums=None, download_size=89742151, post_processing_size=None, dataset_size=178325789, size_in_bytes=None)

# %%
from datasets import load_dataset

# dataset = load_dataset("nyu-mll/glue", "mrpc", split="train")
# dataset = load_dataset('cornell-movie-review-data/rotten_tomatoes', split='train')
dataset = load_dataset('mlabonne/FineTome-Alpaca-100k', split='train')
# Out:
# Generating train split: 100%|██████████| 100000/100000 [00:00<00:00, 121275.90 examples/s]

# %%
dataset[0]
# Out:
# {'source': 'infini-instruct-top-500k',
#  'score': 5.212620735168457,
# ...
